# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.13)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.27.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.26.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.65.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (2.0.12)

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
#  97% 788M/812M [00:03<00:00, 232MB/s]
# 100% 812M/812M [00:03<00:00, 249MB/s]

# %%
from zipfile import ZipFile
dataset='/content/dogs-vs-cats.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print("the dataset is extracted")
# Out:
# the dataset is extracted

# %%
from zipfile import ZipFile
dataset='/content/train.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print("the dataset is extracted")
# Out:
# the dataset is extracted

# %%
import os

path,dirs,files=next(os.walk("/content/train"))
file_count=len(files)
print("Number of images",file_count)
# Out:
# Number of images 25000

# %%
file_name=os.listdir("/content/train")
print(file_name)
# Out:
# ['cat.7106.jpg', 'cat.4505.jpg', 'dog.12176.jpg', 'cat.1757.jpg', 'dog.3643.jpg', 'dog.2399.jpg', 'dog.9373.jpg', 'dog.3865.jpg', 'dog.6573.jpg', 'cat.6362.jpg', 'dog.7173.jpg', 'cat.9442.jpg', 'dog.10273.jpg', 'cat.7384.jpg', 'dog.3165.jpg', 'cat.2736.jpg', 'dog.5429.jpg', 'dog.348.jpg', 'cat.8931.jpg', 'cat.4529.jpg', 'cat.3957.jpg', 'dog.10216.jpg', 'dog.6662.jpg', 'dog.212.jpg', 'cat.8027.jpg', 'dog.9499.jpg', 'cat.3219.jpg', 'cat.10259.jpg', 'cat.1628.jpg', 'cat.4856.jpg', 'cat.11196.jpg', 'cat.6711.jpg', 'cat.929.jpg', 'dog.11925.jpg', 'dog.2209.jpg', 'cat.7224.jpg', 'dog.4236.jpg', 'dog.2314.jpg', 'cat.1112.jpg', 'dog.11850.jpg', 'cat.515.jpg', 'dog.10450.jpg', 'dog.4726.jpg', 'dog.6959.jpg', 'dog.6505.jpg', 'dog.7656.jpg', 'cat.9586.jpg', 'dog.4727.jpg', 'dog.3181.jpg', 'cat.380.jpg', 'cat.689.jpg', 'dog.11731.jpg', 'dog.5595.jpg', 'cat.9787.jpg', 'dog.4278.jpg', 'cat.8437.jpg', 'dog.8076.jpg', 'dog.12255.jpg', 'cat.7907.jpg', 'dog.6177.jpg', 'cat.12314.jpg', 'cat.3870.jpg', 'cat.12293.jpg', 'dog.3124.jpg', 'cat.6967.jpg', 'cat.5198.jpg', 'cat.9231.jpg', 'cat.8778.jpg', 'dog.4734.jpg', 'cat.10702.jpg', 'dog.8015.jpg', 'dog.1317.jpg', 'dog.9533.jpg', 'cat.2029.jpg', 'dog.8619.jpg', 'cat.2648.jpg', 'dog.5093.jpg', 'cat.11497.jpg', 'dog.9045.jpg', 'cat.4737.jpg', 'dog.4892.jpg', 'dog.10942.jpg', 'dog.11107.jpg', 'cat.5939.jpg', 'c
pg', 'cat.188.jpg', 'dog.5020.jpg', 'dog.11846.jpg', 'cat.12163.jpg', 'dog.11024.jpg', 'dog.3988.jpg', 'dog.11046.jpg', 'dog.10379.jpg', 'dog.2616.jpg', 'dog.10568.jpg', 'cat.5789.jpg', 'cat.1085.jpg', 'cat.291.jpg', 'cat.1931.jpg', 'cat.1212.jpg', 'cat.1916.jpg', 'dog.10327.jpg', 'dog.1324.jpg', 'cat.8849.jpg', 'dog.7465.jpg', 'dog.5581.jpg', 'cat.12300.jpg', 'dog.4371.jpg', 'cat.10185.jpg', 'cat.10729.jpg', 'dog.9588.jpg', 'cat.242.jpg', 'cat.2415.jpg', 'cat.5576.jpg', 'cat.11627.jpg', 'dog.3606.jpg', 'dog.6034.jpg', 'dog.2592.jpg', 'cat.2 ...

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from google.colab.patches import cv2_imshow

# %%
img=mpimg.imread('/content/train/dog.12176.jpg')
imgplt=plt.imshow(img)
plt.show()

# %%
img=mpimg.imread('/content/train/cat.4352.jpg')
imgplt=plt.imshow(img)
plt.show()

# %%
file_names = os.listdir('/content/train/')

dog_count = 0
cat_count = 0

for img_file in file_names:

  name = img_file[0:3]

  if name == 'dog':
    dog_count += 1

  else:
    cat_count += 1

print('Number of dog images =', dog_count)
print('Number of cat images =', cat_count)
# Out:
# Number of dog images = 12500
# Number of cat images = 12500

# %%
os.mkdir('/content/image resized')

# %%
original_folder='/content/train/'
resized_folder='/content/image resized/'

for i in range(2000):
  filename=os.listdir(original_folder)[i]
  img_path=original_folder+filename
  img=Image.open(img_path)
  img=img.resize((224,224))
  img=img.convert('RGB')

  newImgPath=resized_folder+filename
  img.save(newImgPath)

# %%
img = mpimg.imread('/content/image resized/dog.10150.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
# creaing a for loop to assign labels
filenames = os.listdir('/content/image resized/')


labels = []

for i in range(2000):

  file_name = filenames[i]
  label = file_name[0:3]

  if label == 'dog':
    labels.append(1)

  else:
    labels.append(0)

# %%
print(filenames[0:5])
print(len(filenames))
# Out:
# ['cat.7106.jpg', 'cat.4505.jpg', 'dog.12176.jpg', 'cat.1757.jpg', 'dog.3643.jpg']
# 2000

# %%
print(labels[0:5])
print(len(labels))
# Out:
# [0, 0, 1, 0, 1]
# 2000

# %%
values, counts = np.unique(labels, return_counts=True)
print(values)
print(counts)
# Out:
# [0 1]
# [ 986 1014]

# %%
import cv2
import glob

# %%
image_directory = '/content/image resized/'
image_extension = ['png', 'jpg']

files = []

[files.extend(glob.glob(image_directory + '*.' + e)) for e in image_extension]

dog_cat_images = np.asarray([cv2.imread(file) for file in files])

# %%
print(dog_cat_images)
# Out:
# [[[[ 74  67  74]
#    [ 71  64  71]
#    [ 69  61  68]
#    ...
#    [ 73  71  90]
#    [ 67  66  82]
#    [ 61  60  76]]
#
#   [[ 72  68  74]
#    [ 71  67  73]
#    [ 73  66  73]
#    ...
#    [ 75  73  92]
#    [ 69  68  84]
#    [ 64  63  79]]
#
#   [[ 90  87  96]
#    [186 204 221]
#    [188 206 223]]
#
#   [[204 216 222]
#    [205 217 223]
#    [204 217 225]
#    ...
#    [187 205 222]
#    [189 207 224]
#    [187 205 222]]]
#
#
#  [[[124  83 255]
#    [121  82 255]
#    [120  81 255]
#    ...
#    [ 83 108 118]
#    [ 80 103 118]
#    [ 87 112 128]]
#
#   [[125  85 255]
#    [122  84 255]
#    [119  83 254]
#    ...
#    [ 76 101 111]
#    [ 74  97 112]
#    [ 80 105 121]]
#
#   [[124  88 255]
#    [122  86 254]
#    [118  83 251]
#    ...
#    [ 77 102 112]
#    [ 78 101 116]
#    [ 81 106 122]]
#
#   ...
#
#   [[ 22  30  47]
#    [ 21  29  46]
#    [ 20  27  46]
#    ...
#    [  4  13  17]
#    [  3  12  16]
#    [  1  10  14]]
#
#   [[ 24  32  49]
#    [ 22  30  47]
#    [ 20  27  46]
#    ...
#    [  5  14  18]
#    [  4  13  17]
#    [  3  12  16]]
#
#   [[ 26  34  51]
#    [ 24  32  49]
#    [ 22  29  48]
#    ...
#    [  6  15  19]
#    [  6  15  19]
#    [  6  15  19]]]
#
#
#  [[[ 25  30  28]
#    [ 25  30  28]
#    [ 25  32  29]
#    ...
#    [ 82 119  73]
#    [ 71 107  61]
#    [ 71 107  61]]
#
#   [[ 26  31  29]
#    [ 25  30  28]
#    [ 24  31  28]
#    ...
#    [103 140  94]
#    [ 87 123  77]
#    [ 76 112  66]]
#
#   [[ 30  35  34]
#    [ 28  33  32]
#    [ 27  32  31]
#    ...
#    [104 141  95]
#    [ 89 126  80]
#    [ 78 115  69]]
#
#   ...
#
#   [[ 81 139  81]
#    [ 81 136  79]
#    [ 89 142  85]
#    ...
#    [ 78 139  81]
#    [ 76 137  79]
#    [ 75 136  78]]
#
#   [[ 77 134  79]
#    [ 77 132  77]
#    [ 87 137  83]
#    ...
#    [ 79 138  80]
#    [ 79 138  80]
#    [ 81 140  82]]
#
#   [[ 81 138  83]
#    [ 81 136  81]
#    [ 94 144  90]
#    ...
#    [ 78 137  79]
#    [ 85 143  85]
#    [ 89 147  89]]]]

# %%
type(dog_cat_images)
# Out:
# numpy.ndarray

# %%
print(dog_cat_images.shape)
# Out:
# (2000, 224, 224, 3)

# %%
X = dog_cat_images
Y = np.asarray(labels)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
# scaling the data
X_train_scaled = X_train/255

X_test_scaled = X_test/255

# %%
print(X_train_scaled)
# Out:
# [[[[0.20784314 0.35686275 0.49411765]
#    [0.21176471 0.36078431 0.49803922]
#    [0.21960784 0.36862745 0.50588235]
#    ...
#    [0.38039216 0.4745098  0.59215686]
#    [0.38431373 0.47843137 0.59607843]
#    [0.38823529 0.48235294 0.6       ]]
#
#   [[0.20784314 0.35686275 0.49411765]
#    [0.21568627 0.36470588 0.50196078]
#    [0.21960784 0.36862745 0.50588235]
#    ...
#    [0.36862745 0.4627451  0.58039216]
#    [0.36862745 0.4627451  0.58039216]
#    [0.36862745 0.4627451  0.58039216]]
#
#   [[0.21176471 0.36078431 0.49803922]
#    [0.21568627 0.36470588 0.50196078]
#    [0.45882353 0.5254902  0.4745098 ]]]
#
#
#  [[[0.94509804 1.         0.94117647]
#    [0.83137255 0.89411765 0.82745098]
#    [0.74509804 0.80784314 0.74117647]
#    ...
#    [0.60784314 0.77647059 0.74117647]
#    [0.60392157 0.77254902 0.7372549 ]
#    [0.60392157 0.77254902 0.7372549 ]]
#
#   [[0.8745098  0.9372549  0.87058824]
#    [0.8        0.8627451  0.79607843]
#    [0.74901961 0.81176471 0.74509804]
#    ...
#    [0.60784314 0.77647059 0.74117647]
#    [0.60392157 0.77254902 0.7372549 ]
#    [0.60392157 0.77254902 0.7372549 ]]
#
#   [[0.81176471 0.8745098  0.80784314]
#    [0.78431373 0.84705882 0.78039216]
#    [0.77254902 0.83529412 0.76862745]
#    ...
#    [0.60784314 0.76862745 0.7372549 ]
#    [0.60784314 0.76862745 0.7372549 ]
#    [0.60784314 0.76862745 0.7372549 ]]
#
#   ...
#
#   [[0.39607843 0.58431373 0.65490196]
#    [0.4        0.58823529 0.65882353]
#    [0.40392157 0.59215686 0.6627451 ]
#    ...
#    [0.6        0.76862745 0.82745098]
#    [0.6        0.76862745 0.82745098]
#    [0.6        0.76862745 0.82745098]]
#
#   [[0.4        0.58823529 0.65882353]
#    [0.40392157 0.59215686 0.6627451 ]
#    [0.40392157 0.59215686 0.6627451 ]
#    ...
#    [0.6        0.76862745 0.82745098]
#    [0.6        0.76862745 0.82745098]
#    [0.6        0.76862745 0.82745098]]
#
#   [[0.4        0.58823529 0.65882353]
#    [0.40392157 0.59215686 0.6627451 ]
#    [0.40784314 0.59607843 0.66666667]
#    ...
#    [0.6        0.76862745 0.82745098]
#    [0.6        0.76862745 0.82745098]
#    [0.6        0.76862745 0.82745098]]]
#
#
#  [[[0.48235294 0.69803922 0.52156863]
#    [0.48235294 0.69803922 0.52156863]
#    [0.48627451 0.69803922 0.52941176]
#    ...
#    [0.56470588 0.43529412 0.33333333]
#    [0.57254902 0.44705882 0.33333333]
#    [0.56078431 0.43529412 0.32156863]]
#
#   [[0.46666667 0.67058824 0.51372549]
#    [0.45882353 0.6627451  0.50588235]
#    [0.45882353 0.65882353 0.50980392]
#    ...
#    [0.55686275 0.42745098 0.3254902 ]
#    [0.56470588 0.43921569 0.3254902 ]
#    [0.55686275 0.43137255 0.31764706]]
#
#   [[0.49411765 0.66666667 0.54509804]
#    [0.48627451 0.65882353 0.5372549 ]
#    [0.48627451 0.65882353 0.5372549 ]
#    ...
#    [0.57254902 0.43529412 0.33333333]
#    [0.57254902 0.44705882 0.33333333]
#    [0.56078431 0.43529412 0.32156863]]
#
#   ...
#
#   [[0.42745098 0.47843137 0.47058824]
#    [0.4745098  0.52941176 0.52156863]
#    [0.30588235 0.36862745 0.36470588]
#    ...
#    [0.25098039 0.43529412 0.28627451]
#    [0.16470588 0.3372549  0.19215686]
#    [0.2745098  0.44705882 0.30196078]]
#
#   [[0.45098039 0.50588235 0.50196078]
#    [0.50980392 0.56470588 0.56078431]
#    [0.38431373 0.44313725 0.45098039]
#    ...
#    [0.2745098  0.44313725 0.31372549]
#    [0.30196078 0.46666667 0.34509804]
#    [0.43137255 0.59607843 0.4745098 ]]
#
#   [[0.45490196 0.50980392 0.50588235]
#    [0.57254902 0.62745098 0.62352941]
#    [0.50980392 0.56862745 0.57647059]
#    ...
#    [0.34901961 0.51372549 0.39215686]
#    [0.43921569 0.6        0.49019608]
#    [0.47843137 0.63921569 0.52941176]]]]

# %%
import tensorflow as tf
import tensorflow_hub as hub

# %%
mobilenet_model = 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'

pretrained_model = hub.KerasLayer(mobilenet_model, input_shape=(224,224,3), trainable=False)

# %%
num_of_classes=2
model = tf.keras.Sequential([
    
    pretrained_model,
    tf.keras.layers.Dense(num_of_classes)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 2)                 2562
#
# =================================================================
# Total params: 2,260,546
# Trainable params: 2,562
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['acc']
)

# %%
model.fit(X_train_scaled, Y_train, epochs=10)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 66s 1s/step - loss: 0.2251 - acc: 0.9031
# Epoch 2/10
# 50/50 [==============================] - 60s 1s/step - loss: 0.0871 - acc: 0.9706
# Epoch 3/10
# 50/50 [==============================] - 64s 1s/step - loss: 0.0666 - acc: 0.9794
# Epoch 4/10
# 50/50 [==============================] - 61s 1s/step - loss: 0.0559 - acc: 0.9800
# Epoch 5/10
# 50/50 [==============================] - 67s 1s/step - loss: 0.0460 - acc: 0.9862
# Epoch 6/10
# 50/50 [==============================] - 63s 1s/step - loss: 0.0375 - acc: 0.9912
# Epoch 7/10
# 50/50 [==============================] - 64s 1s/step - loss: 0.0341 - acc: 0.9912
# Epoch 8/10
# 50/50 [==============================] - 62s 1s/step - loss: 0.0286 - acc: 0.9950
# Epoch 9/10
# 50/50 [==============================] - 62s 1s/step - loss: 0.0248 - acc: 0.9962
# Epoch 10/10
# 50/50 [==============================] - 60s 1s/step - loss: 0.0222 - acc: 0.9962

# %%
score, acc = model.evaluate(X_test_scaled, Y_test)
print('Test Loss =', score)
print('Test Accuracy =', acc)
# Out:
# 13/13 [==============================] - 17s 1s/step - loss: 0.0437 - acc: 0.9800
# Test Loss = 0.04370222985744476
# Test Accuracy = 0.9800000190734863

# %%
input_image_path = input('Path of the image to be predicted: ')

input_image = cv2.imread(input_image_path)

cv2_imshow(input_image)

input_image_resize = cv2.resize(input_image, (224,224))

input_image_scaled = input_image_resize/255

image_reshaped = np.reshape(input_image_scaled, [1,224,224,3])

input_prediction = model.predict(image_reshaped)

print(input_prediction)

input_pred_label = np.argmax(input_prediction)

print(input_pred_label)

if input_pred_label == 0:
  print('The image represents a Cat')

else:
  print('The image represents a Dog')
# Out:
# Path of the image to be predicted: /content/image resized/cat.10999.jpg
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB6E7385F30>
# 1/1 [==============================] - 1s 609ms/step
# [[ 3.6538205 -5.233684 ]]
# 0
# The image represents a Cat
